# %% [markdown]
# # Crop Disease Prediction

# %%
# Import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
import random

# %%
DATADIR = "/home/rahul/Desktop/kibbutz-predict/datasets"
CATEGORIES = ["bacterial-spot", "healthy", "late-blight", "septoria-leaf-spot", "two-spotted-spider-mice", "yellow-leaf-curl-virus"]

for category in CATEGORIES:
    path = os.path.join(DATADIR, category)
    
    for img in os.listdir(path):
        img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
        plt.imshow(img_arr, cmap="gray")
        plt.show()
        break
    break
    
# print(img_arr)

# %%
IMG_SIZE = 150

new_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
plt.imshow(new_arr, cmap="gray")
plt.show()

# %%
train_data = []

def create_train_data():
    for category in CATEGORIES:
        path = os.path.join(DATADIR, category)
        class_num = CATEGORIES.index(category)

        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                new_arr = cv2.resize(img_arr, (IMG_SIZE, IMG_SIZE))
                train_data.append([new_arr, class_num])
            except Exception as e:
                pass
            

create_train_data()

# %%
print(len(train_data))
# Out:
# 120

# %%
random.shuffle(train_data)

# %%
X = []
y = []

# %%
for features, labels in train_data:
    X.append(features)
    y.append(labels)
    
    
X = np.array(X).reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
len(X)
# Out:
# 120

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Conv2D, MaxPooling2D

X = X/255.0

model = Sequential()
model.add(Conv2D(64, (3,3), input_shape = X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, (3,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))

model.add(Dense(4))
model.add(Activation('softmax'))

model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])


model.fit(X, y, batch_size=10, epochs=100, validation_split=0.1)
# Out:
# Train on 108 samples, validate on 12 samples
# Epoch 1/100
# 108/108==============================] - 4s 38ms/sample - loss: 2.3851 - acc: 0.2500 - val_loss: 1.7871 - val_acc: 0.2500
# Epoch 2/100
# 108/108==============================] - 4s 35ms/sample - loss: 1.1754 - acc: 0.5093 - val_loss: 1.4607 - val_acc: 0.2500
# Epoch 3/100
# 108/108==============================] - 4s 35ms/sample - loss: 0.9260 - acc: 0.6204 - val_loss: 1.3357 - val_acc: 0.3333
# Epoch 4/100
# 108/108==============================] - 4s 35ms/sample - loss: 0.5815 - acc: 0.8148 - val_loss: 1.1959 - val_acc: 0.5000
# Epoch 5/100
# 108/108==============================] - 4s 36ms/sample - loss: 0.2924 - acc: 0.9259 - val_loss: 3.0570 - val_acc: 0.2500
# Epoch 6/100
# 108/108==============================] - 4s 37ms/sample - loss: 0.1451 - acc: 0.9722 - val_loss: 2.8235 - val_acc: 0.2500
# Epoch 7/100
# 108/108==============================] - 4s 36ms/sample - loss: 0.0667 - acc: 0.9907 - val_loss: 3.3793 - val_acc: 0.3333
# Epoch 8/100
# 108/108==============================] - 4s 37ms/sample - loss: 0.1247 - acc: 0.9907 - val_loss: 3.1065 - val_acc: 0.2500
# Epoch 9/100
# 108/108==============================] - 4s 36ms/sample - loss: 0.0507 - acc: 0.9907 - val_loss: 3.0494 - val_acc: 0.2500
# Epoch 10/100
# 108/108==============================] - 4s 36ms/sample - loss: 0.0151 - acc: 1.0000 - val_loss: 3.9568 - val_acc: 0.3333
# Epoch 11/100
# 108/108==============================] - 4s 37ms/sample - loss: 0.0054 - acc: 1.0000 - val_loss: 3.5838 - val_acc: 0.2500
# Epoch 12/100
# 108/108==============================] - 4s 36ms/sample - loss: 0.0024 - acc: 1.0000 - val_loss: 4.4169 - val_acc: 0.2500
# Epoch 13/100
# 108/108==============================] - 4s 38ms/sample - loss: 7.9361e-05 - acc: 1.0000 - val_loss: 5.4283 - val_acc: 0.2500
# Epoch 34/100
# 108/108==============================] - 4s 40ms/sample - loss: 6.8470e-05 - acc: 1.0000 - val_loss: 5.5326 - val_acc: 0.2500
# Epoch 35/100
# 108/108==============================] - 4s 37ms/sample - loss: 6.3920e-05 - acc: 1.0000 - val_loss: 5.5750 - val_acc: 0.2500
# Epoch 36/100
# 108/108==============================] - 4s 41ms/sample - loss: 5.7440e-05 - acc: 1.0000 - val_loss: 5.5273 - val_acc: 0.2500
# Epoch 37/100
# 108/108==============================] - 4s 38ms/sample - loss: 5.5137e-05 - acc: 1.0000 - val_loss: 5.5210 - val_acc: 0.2500
# Epoch 38/100
# 108/108==============================] - 4s 37ms/sample - loss: 5.0862e-05 - acc: 1.0000 - val_loss: 5.5723 - val_acc: 0.2500
# Epoch 39/100
# 108/108==============================] - 4s 36ms/sample - loss: 4.7743e-05 - acc: 1.0000 - val_loss: 5.6633 - val_acc: 0.2500
# Epoch 40/100
# 108/108==============================] - 4s 35ms/sample - loss: 4.3799e-05 - acc: 1.0000 - val_loss: 5.6975 - val_acc: 0.2500
# Epoch 41/100
# 108/108==============================] - 4s 35ms/sample - loss: 4.1555e-05 - acc: 1.0000 - val_loss: 5.6968 - val_acc: 0.2500
# Epoch 42/100
# 108/108==============================] - 4s 38ms/sample - loss: 3.9042e-05 - acc: 1.0000 - val_loss: 5.7199 - val_acc: 0.2500
# Epoch 43/100
# 108/108==============================] - 4s 38ms/sample - loss: 3.7517e-05 - acc: 1.0000 - val_loss: 5.7663 - val_acc: 0.2500
# Epoch 44/100
# 108/108==============================] - 5s 46ms/sample - loss: 3.4278e-05 - acc: 1.0000 - val_loss: 5.8323 - val_acc: 0.2500
# Epoch 45/100
# 108/108==============================] - 5s 44ms/sample - loss: 3.3692e-05 - acc: 1.0000 - val_loss: 5.9638 - val_acc: 0.2500
# Epoch 46/100
# 108/108==============================] - 6s 51ms/sample - loss: 3.0877e-05 - acc: 1.0000 - val_loss: 5.8818 - val_acc: 0.2500
# Epoch 47/100
# 108/108==============================] - 4s 37ms/sample - loss: 2.9151e-05 - acc: 1.0000 - val_loss: 5.8766 - val_acc: 0.2500
# Epoch 48/100
# 108/108==============================] - 4s 37ms/sample - loss: 2.7867e-05 - acc: 1.0000 - val_loss: 5.9854 - val_acc: 0.2500
# Epoch 49/100
# 108/108==============================] - 4s 36ms/sample - loss: 2.6019e-05 - acc: 1.0000 - val_loss: 5.9698 - val_acc: 0.2500
# Epoch 50/100
# 108/108==============================] - 4s 36ms/sample - loss: 2.4924e-05 - acc: 1.0000 - val_loss: 6.0090 - val_acc: 0.2500
# Epoch 51/100
# 108/108==============================] - 4s 36ms/sample - loss: 2.3755e-05 - acc: 1.0000 - val_loss: 6.0533 - val_acc: 0.2500
# Epoch 52/100
#  40/108==========>...................] - ETA: 2s - loss: 2.1230e-05 - acc: 1.0000
